# %%
library(tidyverse)
library(ggplot2)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.0 --
#
# v ggplot2 3.3.0     v purrr   0.3.4
# v tibble  3.0.1     v dplyr   1.0.0
# v tidyr   1.0.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.5.0
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
data <- read_csv('C:\\Users\\Md Sohel DELL\\Desktop\\Kaggle\\US Accidents\\US_Accidents_Dec19.csv')
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   TMC = col_double(),
#   Severity = col_double(),
#   Start_Time = col_datetime(format = ""),
#   End_Time = col_datetime(format = ""),
#   Start_Lat = col_double(),
#   Start_Lng = col_double(),
#   End_Lat = col_logical(),
#   End_Lng = col_logical(),
#   `Distance(mi)` = col_double(),
#   Number = col_double(),
#   Weather_Timestamp = col_datetime(format = ""),
#   `Temperature(F)` = col_double(),
#   `Wind_Chill(F)` = col_double(),
#   `Humidity(%)` = col_double(),
#   `Pressure(in)` = col_double(),
#   `Visibility(mi)` = col_double(),
#   `Wind_Speed(mph)` = col_double(),
#   `Precipitation(in)` = col_double(),
#   Amenity = col_logical(),
#   Bump = col_logical()
#   # ... with 11 more columns
# )
#
# See spec(...) for full column specifications.
#
# Warning message:
# "1456142 parsing failures.
# ...

# %%
data
# Out:
#         ID        Source   TMC Severity Start_Time          End_Time
# 1       A-1       MapQuest 201 3        2016-02-08 05:46:00 2016-02-08 11:00:00
# 2       A-2       MapQuest 201 2        2016-02-08 06:07:59 2016-02-08 06:37:59
# 3       A-3       MapQuest 201 2        2016-02-08 06:49:27 2016-02-08 07:19:27
# 4       A-4       MapQuest 201 3        2016-02-08 07:23:34 2016-02-08 07:53:34
# 5       A-5       MapQuest 201 2        2016-02-08 07:39:07 2016-02-08 08:09:07
# 6       A-6       MapQuest 201 3        2016-02-08 07:44:26 2016-02-08 08:14:26
# 7       A-7       MapQuest 201 2        2016-02-08 07:59:35 2016-02-08 08:29:35
# 8       A-8       MapQuest 201 3        2016-02-08 07:59:58 2016-02-08 08:29:58
# 9       A-9       MapQuest 201 2        2016-02-08 08:00:40 2016-02-08 08:30:40
# 10      A-10      MapQuest 201 3        2016-02-08 08:10:04 2016-02-08 08:40:04
# 11      A-11      MapQuest 201 3        2016-02-08 08:14:42 2016-02-08 08:44:42
# ...

# %%
colnames(data)
# Out:
#  [1] "ID"                    "Source"                "TMC"
#  [4] "Severity"              "Start_Time"            "End_Time"
#  [7] "Start_Lat"             "Start_Lng"             "End_Lat"
# [10] "End_Lng"               "Distance(mi)"          "Description"
# [13] "Number"                "Street"                "Side"
# [16] "City"                  "County"                "State"
# [19] "Zipcode"               "Country"               "Timezone"
# [22] "Airport_Code"          "Weather_Timestamp"     "Temperature(F)"
# [25] "Wind_Chill(F)"         "Humidity(%)"           "Pressure(in)"
# [28] "Visibility(mi)"        "Wind_Direction"        "Wind_Speed(mph)"
# [31] "Precipitation(in)"     "Weather_Condition"     "Amenity"
# [34] "Bump"                  "Crossing"              "Give_Way"
# [37] "Junction"              "No_Exit"               "Railway"
# [40] "Roundabout"            "Station"               "Stop"
# [43] "Traffic_Calming"       "Traffic_Signal"        "Turning_Loop"
# ...

# %%
uni<-unique(data$State)
uni
# Out:
#  [1] "OH" "WV" "CA" "FL" "GA" "SC" "NE" "IA" "IL" "MO" "WI" "IN" "MI" "NJ" "NY"
# [16] "CT" "MA" "RI" "NH" "PA" "KY" "MD" "VA" "DC" "DE" "TX" "WA" "OR" "AL" "NC"
# [31] "MN" "OK" "LA" "TN" "UT" "CO" "AZ" "NV" "KS" "MS" "NM" "ME" "AR" "WY" "VT"
# [46] "ID" "ND" "MT" "SD"

# %%
# length(uni)
# tib<-as_tibble(unique(data$State))

# %%
# oh<- filter(data,State==uni[1])

# %%
# length(oh$ID)

# %%
data_by_state<-NULL
for (i in 1:length(uni)){
    data_by_state[i] <- length(filter(data, State==uni[i])$ID) 
    }

# %%
data_by_state
uni
# Out:
#  [1]  55863   2274 663204 223746  83620 146689  22505  10346  86390  29012
# [11]  17580  30040  88694  49942 137799  22803  33014  10483   7064  90395
# [21]  19122  43328  79957   3653   4434 298062  61367  70840  36369 142460
# [31]  62727  51297  52481  58289  41385  40124  62330   9524   6887   5961
# [41]   5020   2065   1749    492    585   1757     43    504     60
#  [1] "OH" "WV" "CA" "FL" "GA" "SC" "NE" "IA" "IL" "MO" "WI" "IN" "MI" "NJ" "NY"
# [16] "CT" "MA" "RI" "NH" "PA" "KY" "MD" "VA" "DC" "DE" "TX" "WA" "OR" "AL" "NC"
# [31] "MN" "OK" "LA" "TN" "UT" "CO" "AZ" "NV" "KS" "MS" "NM" "ME" "AR" "WY" "VT"
# [46] "ID" "ND" "MT" "SD"

# %%
# x<-reorder(uni,data_by_state)
# y<-sort(data_by_state)

# %%
barplot_data<-cbind(uni,data_by_state)

# %%
barplot_data_frame<-data.frame(barplot_data)
barplot_data_frame
# Out:
#    uni data_by_state
# 1  OH  55863
# 2  WV  2274
# 3  CA  663204
# 4  FL  223746
# 5  GA  83620
# 6  SC  146689
# 7  NE  22505
# 8  IA  10346
# 9  IL  86390
# 10 MO  29012
# 11 WI  17580
# 12 IN  30040
# 13 MI  88694
# 14 NJ  49942
# 15 NY  137799
# 16 CT  22803
# 17 MA  33014
# 18 RI  10483
# 19 NH  7064
# 20 PA  90395
# 21 KY  19122
# 22 MD  43328
# 23 VA  79957
# 24 DC  3653
# 25 DE  4434
# 26 TX  298062
# 27 WA  61367
# 28 OR  70840
# 29 AL  36369
# 30 NC  142460
# 31 MN  62727
# 32 OK  51297
# 33 LA  52481
# 34 TN  58289
# 35 UT  41385
# 36 CO  40124
# 37 AZ  62330
# 38 NV  9524
# 39 KS  6887
# 40 MS  5961
# 41 NM  5020
# 42 ME  2065
# 43 AR  1749
# 44 WY  492
# 45 VT  585
# 46 ID  1757
# 47 ND  43
# 48 MT  504
# 49 SD  60

# %%
set_plot_dimensions <- function(width_choice, height_choice) {
        options(repr.plot.width=width_choice, repr.plot.height=height_choice)
        }

# %%
set_plot_dimensions(50,25)
par(bg = "white")
x<-reorder(uni,-data_by_state)
y<-data_by_state

ggplot(barplot_data_frame,aes(x=x, y=y,fill=y))+
    geom_bar(stat = 'identity')+
    scale_fill_gradient(low="blue", high="red")+
    theme(axis.text.x = element_text(colour = "red", size = 40,angle=90),
        axis.text.y = element_text(colour = "blue", size = 40))
# Out:
# plot without title

# %%
tab<-table(data$State)
tab
# Out:
#     AL     AR     AZ     CA     CO     CT     DC     DE     FL     GA     IA
#  36369   1749  62330 663204  40124  22803   3653   4434 223746  83620  10346
#     ID     IL     IN     KS     KY     LA     MA     MD     ME     MI     MN
#   1757  86390  30040   6887  19122  52481  33014  43328   2065  88694  62727
#     MO     MS     MT     NC     ND     NE     NH     NJ     NM     NV     NY
#  29012   5961    504 142460     43  22505   7064  49942   5020   9524 137799
#     OH     OK     OR     PA     RI     SC     SD     TN     TX     UT     VA
#  55863  51297  70840  90395  10483 146689     60  58289 298062  41385  79957
#     VT     WA     WI     WV     WY
#    585  61367  17580   2274    492

# %%
ordered_data<-sort(tab, decreasing = T)
ordered_data
# Out:
#     CA     TX     FL     SC     NC     NY     PA     MI     IL     GA     VA
# 663204 298062 223746 146689 142460 137799  90395  88694  86390  83620  79957
#     OR     MN     AZ     WA     TN     OH     LA     OK     NJ     MD     UT
#  70840  62727  62330  61367  58289  55863  52481  51297  49942  43328  41385
#     CO     AL     MA     IN     MO     CT     NE     KY     WI     RI     IA
#  40124  36369  33014  30040  29012  22803  22505  19122  17580  10483  10346
#     NV     NH     KS     MS     NM     DE     DC     WV     ME     ID     AR
#   9524   7064   6887   5961   5020   4434   3653   2274   2065   1757   1749
#     VT     MT     WY     SD     ND
#    585    504    492     60     43

# %%
# set_plot_dimensions(40,20)
# par(bg = "white")
barplot(ordered_data,col=rainbow(50),border = "black",font.axis=4,col.axis="red",cex.axis=3,cex.names=3,
        las=3)
# Out:
# plot without title
